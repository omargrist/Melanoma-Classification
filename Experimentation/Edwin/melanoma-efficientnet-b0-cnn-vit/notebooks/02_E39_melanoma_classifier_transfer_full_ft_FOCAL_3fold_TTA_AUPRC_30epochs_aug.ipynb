# %% [markdown]
# # Melanoma Classification

# %%
# Install any missing packages
# !pip install torchvision -q

import sys
print(f"Python {sys.version}")

import torch, torchvision
print(f"PyTorch {torch.__version__}")
print(f"Torchvision {torchvision.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")

# %%
# Choose where to save outputs inside Drive
import os
OUTPUT_DIR = '/AML_Project/outputs'
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Outputs will be saved to: {OUTPUT_DIR}")

# %% [markdown]
# ## Imports

# %%
import os
import time
import math
from datetime import datetime
from pathlib import Path

import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import models, transforms
from torchvision.ops import sigmoid_focal_loss
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import torch.nn.functional as F

from sklearn.metrics import average_precision_score
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.metrics import (
    roc_auc_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_curve, 
    precision_recall_curve
)



from IPython.display import clear_output, display

# %%
import os
import zipfile

zip_path = '/AML_Project/JPEG Melanoma 224x224.zip'
data_path = '/AML_Project/inputs/siim_isic_224'
extract_path = '/AML_Project/inputs/'

if not os.path.exists(data_path) or len(os.listdir(data_path)) == 0:
    print("Extracting dataset...")
    with zipfile.ZipFile(zip_path, "r") as z:
        z.extractall(extract_path)
else:
    print("Dataset already extracted. Skipping.")
# Out:
# Dataset already extracted. Skipping.

# %%
# ── Adjust these paths to match your environment ──────────────────────
DATA_DIR  = Path("/AML_Project/inputs/siim_isic_224")   # root folder of the dataset
CSV_PATH  = DATA_DIR / "train_resized_224.csv"
IMAGE_DIR = DATA_DIR / "train"
# ─────────────────────────────────────────────────────────────────────────────

df = pd.read_csv(CSV_PATH)

COLUMNS = ["image_name", "patient_id", "sex", "age_approx", "anatom_site_general_challenge", "diagnosis",
        "benign_malignant", "target", "resized_path"]
df = df[COLUMNS].copy()

df["image_path"] = str(IMAGE_DIR) + "/" + df["image_name"] + ".jpg"

print("--- Dataset Overview ---")
print(df.head())
print(f"\nColumns: {list(df.columns)}")
print(f"Total rows: {len(df)}")
print(f"Unique patients: {df['patient_id'].nunique()}")
print(f"Missing patient IDs: {df['patient_id'].isna().sum()}")
# Out:
# --- Dataset Overview ---
#      image_name  patient_id     sex  age_approx anatom_site_general_challenge  \
# 0  ISIC_2637011  IP_7279968    male        45.0                     head/neck
# 1  ISIC_0015719  IP_3075186  female        45.0               upper extremity
# 2  ISIC_0052212  IP_2842074  female        50.0               lower extremity
# 3  ISIC_0068279  IP_6890425  female        45.0                     head/neck
# 4  ISIC_0074268  IP_8723313  female        55.0               upper extremity
#
#   diagnosis benign_malignant  target  \
# 0   unknown           benign       0
# 1   unknown           benign       0
# 2     nevus           benign       0
# 3   unknown           benign       0
# 4   unknown           benign       0
#
#                                         resized_path  \
# 0  /kaggle/working/siim_isic_224/train/ISIC_26370...
# 1  /kaggle/working/siim_isic_224/train/ISIC_00157...
# 2  /kaggle/working/siim_isic_224/train/ISIC_00522...
# 3  /kaggle/working/siim_isic_224/train/ISIC_00682...
# 4  /kaggle/working/siim_isic_224/train/ISIC_00742...
#
#                                           image_path
# 0  /user/HS401/ep01372/Documents/AML_Project/inpu...
# 1  /user/HS401/ep01372/Documents/AML_Project/inpu...
# 2  /user/HS401/ep01372/Documents/AML_Project/inpu...
# 3  /user/HS401/ep01372/Documents/AML_Project/inpu...
# 4  /user/HS401/ep01372/Documents/AML_Project/inpu...
#
# Columns: ['image_name', 'patient_id', 'sex', 'age_approx', 'anatom_site_general_challenge', 'diagnosis', 'benign_malignant', 'target', 'resized_path', 'image_path']
# Total rows: 33126
# Unique patients: 2056
# Missing patient IDs: 0

# %% [markdown]
# ## Sanity check — peek at one image

# %%
sample_image_path = df.loc[0, "image_path"]
sample_label = df.loc[0, "target"]

print(f"Sample image path: {sample_image_path}")
print(f"Label (0=benign, 1=melanoma): {sample_label}")

sample_image = Image.open(sample_image_path).convert("RGB")
print(f"Image dimensions: {sample_image.size}")
sample_image
# Out:
# Sample image path: /user/HS401/ep01372/Documents/AML_Project/inputs/siim_isic_224/train/ISIC_2637011.jpg
# Label (0=benign, 1=melanoma): 0
# Image dimensions: (224, 224)
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ## Train / Validation split (patient-level)

# %%
from sklearn.model_selection import StratifiedGroupKFold

N_SPLITS = 3
FOLDS_TO_RUN = [0, 1, 2]
RANDOM_STATE = 42

df = df.sort_values("image_name").reset_index(drop=True)

cv_splitter = StratifiedGroupKFold(
    n_splits=N_SPLITS,
    shuffle=True,
    random_state=RANDOM_STATE
)

fold_splits = []
for fold, (train_idx, val_idx) in enumerate(
    cv_splitter.split(df, df["target"], groups=df["patient_id"])
):
    if fold in FOLDS_TO_RUN:
        fold_splits.append((fold, train_idx, val_idx))

print(f"Prepared folds: {FOLDS_TO_RUN}")
# Out:
# Prepared folds: [0, 1, 2]

# %% [markdown]
# ## Dataset class

# %%
class MelanomaDataset(Dataset):
    """Custom PyTorch Dataset for binary melanoma classification."""

    def __init__(self, dataframe, transform=None):
        self.data = dataframe.reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        image = Image.open(row["image_path"]).convert("RGB")
        label = torch.tensor(row["target"], dtype=torch.float32)
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %% [markdown]
# ## DataLoaders

# %%
TRAIN_BATCH_SIZE = 64
VAL_BATCH_SIZE   = 256
NUM_WORKERS      = 4

IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD  = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomRotation(degrees=20),
    transforms.ColorJitter(
        brightness=0.15,
        contrast=0.15,
        saturation=0.10,
        hue=0.02
    ),
    transforms.RandomAffine(
        degrees=0,
        translate=(0.05, 0.05),
        scale=(0.95, 1.05)
    ),
    transforms.ToTensor(),
    transforms.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)
])

def make_train_loader(train_df):
    train_dataset = MelanomaDataset(train_df, transform=train_transform)

    if imbalance_strategy == "weighted_sampler":
        labels = train_df["target"].values.astype(int)
        class_counts = np.bincount(labels)
        class_weights = 1.0 / class_counts
        sample_weights = class_weights[labels]
        sample_weights = torch.as_tensor(sample_weights, dtype=torch.double)

        sampler = WeightedRandomSampler(
            weights=sample_weights,
            num_samples=len(sample_weights),
            replacement=True
        )

        train_loader = DataLoader(
            train_dataset,
            batch_size=TRAIN_BATCH_SIZE,
            sampler=sampler,
            num_workers=NUM_WORKERS,
            pin_memory=torch.cuda.is_available(),
            persistent_workers=(NUM_WORKERS > 0)
        )
    else:
        train_loader = DataLoader(
            train_dataset,
            batch_size=TRAIN_BATCH_SIZE,
            shuffle=True,
            num_workers=NUM_WORKERS,
            pin_memory=torch.cuda.is_available(),
            persistent_workers=(NUM_WORKERS > 0)
        )

    return train_loader

def make_val_loader(val_df):
    val_dataset = MelanomaDataset(val_df, transform=val_transform)
    val_loader = DataLoader(
        val_dataset,
        batch_size=VAL_BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=torch.cuda.is_available(),
        persistent_workers=(NUM_WORKERS > 0)
    )
    return val_loader

# %% [markdown]
# ## Model — EfficientNet-B0

# %%
class MelanomaClassifier(nn.Module):
    """
    EfficientNet-B0 adapted for binary melanoma classification.
    The 1000-class head is replaced with a single linear neuron
    that outputs one logit for BCEWithLogitsLoss / Focal Loss.
    """

    def __init__(self, weights_path=None):
        super().__init__()

        if weights_path and Path(weights_path).exists():
            # --- Offline weights ---
            self.model = models.efficientnet_b0(weights=None)
            state_dict = torch.load(weights_path, map_location='cpu', weights_only=True)
            self.model.load_state_dict(state_dict)
            print(f"Loaded offline weights from {weights_path}")
        else:
            # --- Download from torchvision (requires internet) ---
            self.model = models.efficientnet_b0(weights='IMAGENET1K_V1')
            print("Downloaded ImageNet weights from torchvision")

        # Replace 1000-class head with binary head
        in_features = self.model.classifier[1].in_features
        self.model.classifier[1] = nn.Linear(in_features, 1)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Model setup

# %%
# ── Adjust these paths if you have offline weights / a prior checkpoint ──
PRETRAINED_WEIGHTS_PATH = '/AML_Project/inputs/efficientnet_b0_rwightman-7f5810bc.pth'
TRANSFER_MODEL_PATH     = "/AML_Project/inputs/efficientnet_b0_final_pre_train_full_ft_5fold_AUPRC_20epochs_balanced_bce_best_model.pth"
# ─────────────────────────────────────────────────────────────────────────

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device:", device)

def build_model():
    model = MelanomaClassifier(weights_path=PRETRAINED_WEIGHTS_PATH)

    if TRANSFER_MODEL_PATH and Path(TRANSFER_MODEL_PATH).exists():
        state_dict = torch.load(TRANSFER_MODEL_PATH, map_location="cpu", weights_only=True)
        model.load_state_dict(state_dict)
        print(f"Loaded baseline checkpoint from {TRANSFER_MODEL_PATH}")

    in_features = model.model.classifier[1].in_features
    model.model.classifier[1] = nn.Linear(in_features, 1)

    for param in model.parameters():
        param.requires_grad = True

    model = model.to(device)
    return model
# Out:
# Device: cuda:0

# %% [markdown]
# ## Loss function & optimiser

# %%
# --- Loss function and optimiser ---
LEARNING_RATE = 1e-5
WEIGHT_DECAY = 1e-4

FOCAL_ALPHA = 0.75
FOCAL_GAMMA = 2.0


class BinaryFocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2.0, reduction="mean"):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        targets = targets.float()

        ce_loss = F.binary_cross_entropy_with_logits(
            inputs,
            targets,
            reduction="none"
        )

        p = torch.sigmoid(inputs)
        p_t = p * targets + (1 - p) * (1 - targets)

        loss = ce_loss * ((1 - p_t) ** self.gamma)

        if self.alpha >= 0:
            alpha_t = self.alpha * targets + (1 - self.alpha) * (1 - targets)
            loss = alpha_t * loss

        if self.reduction == "mean":
            return loss.mean()
        elif self.reduction == "sum":
            return loss.sum()
        elif self.reduction == "none":
            return loss
        else:
            raise ValueError(f"Invalid reduction: {self.reduction}")


def build_training_components(model, train_df):
    criterion = BinaryFocalLoss(
        alpha=FOCAL_ALPHA,
        gamma=FOCAL_GAMMA,
        reduction="mean"
    ).to(device)

    trainable_parameters = filter(lambda p: p.requires_grad, model.parameters())
    optimiser = optim.Adam(
        trainable_parameters,
        lr=LEARNING_RATE,
        weight_decay=WEIGHT_DECAY
    )

    return criterion, optimiser

# %% [markdown]
# ## Experiment setup — output paths & logging

# %%
imbalance_strategy = None   # "pos_weight" or "weighted_sampler"
#EXPERIMENT_NAME = f"efficientnet_b0_transfer_full_ft_FOCAL_3fold_TTA_AUPRC_20epochs_{imbalance_strategy}_aug"

EXPERIMENT_NAME = f"efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug"

WORKING_DIR = Path(OUTPUT_DIR)
WORKING_DIR.mkdir(parents=True, exist_ok=True)

def get_fold_paths(fold_idx):
    best_model_path      = WORKING_DIR / f"{EXPERIMENT_NAME}_fold_{fold_idx}_best_model.pth"
    last_checkpoint_path = WORKING_DIR / f"{EXPERIMENT_NAME}_fold_{fold_idx}_last_checkpoint.pth"
    log_path             = WORKING_DIR / f"{EXPERIMENT_NAME}_fold_{fold_idx}_training_log.txt"
    return best_model_path, last_checkpoint_path, log_path

def log_message(message, log_path, printing=False):
    if printing:
        print(message)
    with open(log_path, "a") as f:
        f.write(message + "\n")

# %% [markdown]
# ## Training & validation functions

# %%
def train_one_epoch(model, dataloader, criterion, optimiser, device, log_path=None):
    model.train()
    running_loss = correct = total = 0
    epoch_start = time.perf_counter()
    all_probs, all_labels = [], []

    for batch_idx, (images, labels) in enumerate(dataloader, start=1):
        images = images.to(device, non_blocking=True)
        labels = labels.unsqueeze(1).to(device, non_blocking=True)

        optimiser.zero_grad(set_to_none=True)
        logits = model(images)
        loss   = criterion(logits, labels)
        loss.backward()
        optimiser.step()

        probs      = torch.sigmoid(logits)
        pred       = (probs >= 0.5).float()

        bs         = images.size(0)
        running_loss += loss.item() * bs
        correct      += (pred == labels).sum().item()
        total        += bs

        all_probs.extend(probs.squeeze(1).detach().cpu().numpy())
        all_labels.extend(labels.squeeze(1).detach().cpu().numpy())

        if (batch_idx % 10 == 0 or batch_idx == len(dataloader)) and log_path is not None: 
            elapsed = time.perf_counter() - epoch_start
            log_message(
                f"Train [{batch_idx}/{len(dataloader)}] "
                f"Loss: {running_loss/total:.4f} "
                f"Acc: {correct/total:.4f} "
                f"Elapsed: {elapsed:.1f}s",
                log_path=log_path,
                printing=False
            )

    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)

    return {
        "loss":     running_loss / total,
        "accuracy": correct / total,
        "auroc":    roc_auc_score(all_labels, all_probs),
        "auprc": average_precision_score(all_labels, all_probs),
    }


def validate_one_epoch(model, dataloader, criterion, device, use_tta=False, log_path=None):
    model.eval()
    running_loss = correct = total = 0
    epoch_start = time.perf_counter()
    all_probs, all_labels, all_preds = [], [], []

    with torch.no_grad():
        for batch_idx, (images, labels) in enumerate(dataloader, start=1):
            images = images.to(device, non_blocking=True)
            labels = labels.unsqueeze(1).to(device, non_blocking=True)

            if use_tta:
                logits_orig = model(images)
                loss_orig = criterion(logits_orig, labels)
                probs_orig  = torch.sigmoid(logits_orig)
                
                
                logits_hflip = model(torch.flip(images, dims=[3]))
                loss_hflip = criterion(logits_hflip, labels)
                probs_hflip  = torch.sigmoid(logits_hflip)

                loss = 0.5 * (loss_orig + loss_hflip)
                probs = 0.5 * (probs_orig + probs_hflip)

            else:
                logits = model(images)
                loss   = criterion(logits, labels)
                probs  = torch.sigmoid(logits)
            
        
            pred   = (probs >= 0.5).float()

            bs     = images.size(0)
            running_loss += loss.item() * bs
            correct      += (pred == labels).sum().item()
            total        += bs

            all_probs.extend(probs.squeeze(1).cpu().numpy())
            all_labels.extend(labels.squeeze(1).cpu().numpy())
            all_preds.extend(pred.squeeze(1).cpu().numpy())

            if batch_idx % 10 == 0 or batch_idx == len(dataloader):
                elapsed = time.perf_counter() - epoch_start
                if log_path is not None:
                    log_message(
                        f"Val [{batch_idx}/{len(dataloader)}] "
                        f"Loss: {running_loss/total:.4f} "
                        f"Acc: {correct/total:.4f} "
                        f"Elapsed: {elapsed:.1f}s",
                        log_path=log_path,
                        printing=False
                    )

    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    cm = confusion_matrix(all_labels, all_preds, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0

    return {
        "loss": running_loss / total,
        "accuracy": correct / total,
        "auroc": roc_auc_score(all_labels, all_probs),
        "auprc": average_precision_score(all_labels, all_probs),
        "precision": precision_score(all_labels, all_preds, zero_division=0),
        "recall": recall_score(all_labels, all_preds, zero_division=0),
        "f1": f1_score(all_labels, all_preds, zero_division=0),
        "specificity": specificity,
        "confusion_matrix": cm,
        "all_probs": all_probs,
        "all_labels": all_labels,
        "all_preds": all_preds,
    }

# %%
def threshold_sweep(y_true, y_prob, thresholds=np.arange(0.05, 0.96, 0.05)):
    results = []

    for thr in thresholds:
        y_pred = (y_prob >= thr).astype(int)
        cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
        tn, fp, fn, tp = cm.ravel()

        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0

        results.append({
            "threshold": float(thr),
            "precision": precision_score(y_true, y_pred, zero_division=0),
            "recall": recall_score(y_true, y_pred, zero_division=0),
            "f1": f1_score(y_true, y_pred, zero_division=0),
            "specificity": specificity,
        })

    return pd.DataFrame(results)

# %% [markdown]
# ## Training loop

# %%
num_epochs = 30
USE_TTA = False
checkpoint_metric = "auprc"   # "auroc" or "auprc"

all_fold_results = []

full_training_start = time.perf_counter()

for fold_idx, train_idx, val_idx in fold_splits:
    print(f"\n===== Fold {fold_idx} =====")

    train_df = df.iloc[train_idx].reset_index(drop=True)
    val_df   = df.iloc[val_idx].reset_index(drop=True)

    print(f"Train size: {len(train_df)} | positives: {int(train_df['target'].sum())}")
    print(f"Val size:   {len(val_df)} | positives: {int(val_df['target'].sum())}")

    train_loader = make_train_loader(train_df)
    val_loader = make_val_loader(val_df)

    model = build_model()
    criterion, optimiser = build_training_components(model, train_df)
 
    BEST_MODEL_PATH, LAST_CHECKPOINT_PATH, LOG_PATH = get_fold_paths(fold_idx)

    with open(LOG_PATH, "w") as f:
        f.write(f"Training log started at {datetime.now()}\n\n")

    best_val_metric = -1.0
    best_epoch = -1

    fold_history = {
        "epoch": [],
        "train_loss": [],
        "val_loss": [],
        "train_auroc": [],
        "val_auroc": [],
        "val_auprc": [],
        "val_f1": [],
    }

    for epoch in range(1, num_epochs + 1):
        epoch_start = time.perf_counter()
        current_lr = optimiser.param_groups[0]["lr"]

        log_message(
            f"Starting epoch {epoch}/{num_epochs}... | LR: {current_lr:.8f}",
            log_path=LOG_PATH,
            printing=True
        )

        train_metrics = train_one_epoch(model, train_loader, criterion, optimiser, device, log_path=LOG_PATH)
        val_metrics   = validate_one_epoch(model, val_loader, criterion, device, use_tta=USE_TTA, log_path=LOG_PATH)

        epoch_duration = time.perf_counter() - epoch_start

        fold_history["epoch"].append(epoch)
        fold_history["train_loss"].append(train_metrics["loss"])
        fold_history["val_loss"].append(val_metrics["loss"])
        fold_history["train_auroc"].append(train_metrics["auroc"])
        fold_history["val_auroc"].append(val_metrics["auroc"])
        fold_history["val_auprc"].append(val_metrics["auprc"])
        fold_history["val_f1"].append(val_metrics["f1"])

        log_message(
            f"Validation | Loss: {val_metrics['loss']:.4f} | Acc: {val_metrics['accuracy']:.4f} | "
            f"AUROC: {val_metrics['auroc']:.4f} | AUPRC: {val_metrics['auprc']:.4f} | "
            f"Precision: {val_metrics['precision']:.4f} | Recall: {val_metrics['recall']:.4f} | "
            f"Specificity: {val_metrics['specificity']:.4f} | F1: {val_metrics['f1']:.4f}",
            log_path=LOG_PATH,
            printing=True
        )

        cm = val_metrics["confusion_matrix"]
        tn, fp, fn, tp = cm.ravel()
        log_message(
            f"Confusion Matrix: TN={tn}  FP={fp}  FN={fn}  TP={tp}",
            log_path=LOG_PATH,
            printing=True
        )

        log_message(
            f"Epoch duration: {epoch_duration:.1f}s ({epoch_duration / 60:.2f} min)",
            log_path=LOG_PATH,
            printing=True
        )
        log_message("-" * 60, log_path=LOG_PATH, printing=True)

        current_metric = val_metrics[checkpoint_metric]
        if not math.isnan(current_metric) and current_metric > best_val_metric:
            best_val_metric = current_metric
            best_epoch = epoch
            torch.save(model.state_dict(), BEST_MODEL_PATH)
            log_message(
                f"Best model saved ({checkpoint_metric.upper()} {best_val_metric:.4f})",
                log_path=LOG_PATH,
                printing=True
            )


        torch.save(
            {
                "epoch": epoch,
                "model_state_dict": model.state_dict(),
                "optimiser_state_dict": optimiser.state_dict(),
                "best_val_metric": best_val_metric,
                "checkpoint_metric": checkpoint_metric,
            },
            LAST_CHECKPOINT_PATH
        )

    history_df = pd.DataFrame(fold_history)
    history_path = WORKING_DIR / f"{EXPERIMENT_NAME}_fold_{fold_idx}_history.csv"
    history_df.to_csv(history_path, index=False)

    print(f"Fold {fold_idx} best {checkpoint_metric.upper()}: {best_val_metric:.4f} (epoch {best_epoch})")
    print(f"Saved history to: {history_path}")

    all_fold_results.append(
        {
            "fold": fold_idx,
            "best_metric": best_val_metric,
            "best_epoch": best_epoch,
            "best_model_path": str(BEST_MODEL_PATH),
            "history_path": str(history_path),
            "checkpoint_metric": checkpoint_metric,
        }
    )

full_training_end = time.perf_counter()
total_training_time = full_training_end - full_training_start

summary_log_path = WORKING_DIR / f"{EXPERIMENT_NAME}_cv_summary.txt"
with open(summary_log_path, "w") as f:
    f.write("===== Cross-validation summary =====\n")
    for result in all_fold_results:
        f.write(
            f"Fold {result['fold']} | "
            f"Best {result['checkpoint_metric'].upper()}: {result['best_metric']:.4f} | "
            f"Best epoch: {result['best_epoch']}\n"
        )

    mean_best_metric = np.mean([x["best_metric"] for x in all_fold_results])
    f.write(f"\nMean best {checkpoint_metric.upper()} across folds: {mean_best_metric:.4f}\n")
    f.write(f"Total full training loop time: {total_training_time:.1f}s ({total_training_time / 60:.2f} min)\n")

print(f"Saved CV summary to: {summary_log_path}")
# Out:
# ===== Fold 0 =====
# Train size: 22080 | positives: 390
# Val size:   11046 | positives: 194
# Loaded offline weights from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_rwightman-7f5810bc.pth
# Loaded baseline checkpoint from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_final_pre_train_full_ft_5fold_AUPRC_20epochs_balanced_bce_best_model.pth
# Starting epoch 1/30... | LR: 0.00001000
# Validation | Loss: 0.0178 | Acc: 0.9684 | AUROC: 0.6954 | AUPRC: 0.0432 | Precision: 0.0670 | Recall: 0.0619 | Specificity: 0.9846 | F1: 0.0643
# Confusion Matrix: TN=10685  FP=167  FN=182  TP=12
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.0432)
# Starting epoch 2/30... | LR: 0.00001000
# Validation | Loss: 0.0140 | Acc: 0.9759 | AUROC: 0.7642 | AUPRC: 0.0760 | Precision: 0.1170 | Recall: 0.0567 | Specificity: 0.9924 | F1: 0.0764
# Confusion Matrix: TN=10769  FP=83  FN=183  TP=11
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.0760)
# Starting epoch 3/30... | LR: 0.00001000
# Validation | Loss: 0.0134 | Acc: 0.9721 | AUROC: 0.7900 | AUPRC: 0.0946 | Precision: 0.1392 | Recall: 0.1134 | Specificity: 0.9875 | F1: 0.1250
# Confusion Matrix: TN=10716  FP=136  FN=172  TP=22
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.0946)
# Starting epoch 4/30... | LR: 0.00001000
# Validation | Loss: 0.0122 | Acc: 0.9757 | AUROC: 0.8216 | AUPRC: 0.1146 | Precision: 0.2063 | Recall: 0.1340 | Specificity: 0.9908 | F1: 0.1625
# Confusion Matrix: TN=10752  FP=100  FN=168  TP=26
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1146)
# Starting epoch 5/30... | LR: 0.00001000
# Validation | Loss: 0.0118 | Acc: 0.9748 | AUROC: 0.8384 | AUPRC: 0.1328 | Precision: 0.2123 | Recall: 0.1598 | Specificity: 0.9894 | F1: 0.1824
# Confusion Matrix: TN=10737  FP=115  FN=163  TP=31
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1328)
# Starting epoch 6/30... | LR: 0.00001000
# Validation | Loss: 0.0115 | Acc: 0.9752 | AUROC: 0.8436 | AUPRC: 0.1415 | Precision: 0.2222 | Recall: 0.1649 | Specificity: 0.9897 | F1: 0.1893
# Confusion Matrix: TN=10740  FP=112  FN=162  TP=32
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1415)
# Starting epoch 7/30... | LR: 0.00001000
# Validation | Loss: 0.0114 | Acc: 0.9758 | AUROC: 0.8473 | AUPRC: 0.1537 | Precision: 0.2256 | Recall: 0.1546 | Specificity: 0.9905 | F1: 0.1835
# Confusion Matrix: TN=10749  FP=103  FN=164  TP=30
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1537)
# Starting epoch 8/30... | LR: 0.00001000
# Validation | Loss: 0.0112 | Acc: 0.9759 | AUROC: 0.8529 | AUPRC: 0.1652 | Precision: 0.2231 | Recall: 0.1495 | Specificity: 0.9907 | F1: 0.1790
# Confusion Matrix: TN=10751  FP=101  FN=165  TP=29
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1652)
# Starting epoch 9/30... | LR: 0.00001000
# Validation | Loss: 0.0113 | Acc: 0.9728 | AUROC: 0.8572 | AUPRC: 0.1649 | Precision: 0.2151 | Recall: 0.2062 | Specificity: 0.9865 | F1: 0.2105
# Confusion Matrix: TN=10706  FP=146  FN=154  TP=40
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 10/30... | LR: 0.00001000
# Validation | Loss: 0.0110 | Acc: 0.9763 | AUROC: 0.8584 | AUPRC: 0.1722 | Precision: 0.2536 | Recall: 0.1804 | Specificity: 0.9905 | F1: 0.2108
# Confusion Matrix: TN=10749  FP=103  FN=159  TP=35
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1722)
# Starting epoch 11/30... | LR: 0.00001000
# Validation | Loss: 0.0111 | Acc: 0.9737 | AUROC: 0.8604 | AUPRC: 0.1705 | Precision: 0.2164 | Recall: 0.1907 | Specificity: 0.9877 | F1: 0.2027
# Confusion Matrix: TN=10718  FP=134  FN=157  TP=37
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 12/30... | LR: 0.00001000
# Validation | Loss: 0.0112 | Acc: 0.9750 | AUROC: 0.8615 | AUPRC: 0.1809 | Precision: 0.2437 | Recall: 0.2010 | Specificity: 0.9888 | F1: 0.2203
# Confusion Matrix: TN=10731  FP=121  FN=155  TP=39
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1809)
# Starting epoch 13/30... | LR: 0.00001000
# Validation | Loss: 0.0109 | Acc: 0.9738 | AUROC: 0.8714 | AUPRC: 0.1863 | Precision: 0.2460 | Recall: 0.2371 | Specificity: 0.9870 | F1: 0.2415
# Confusion Matrix: TN=10711  FP=141  FN=148  TP=46
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1863)
# Starting epoch 14/30... | LR: 0.00001000
# Validation | Loss: 0.0112 | Acc: 0.9694 | AUROC: 0.8696 | AUPRC: 0.1872 | Precision: 0.2165 | Recall: 0.2835 | Specificity: 0.9817 | F1: 0.2455
# Confusion Matrix: TN=10653  FP=199  FN=139  TP=55
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1872)
# Starting epoch 15/30... | LR: 0.00001000
# Validation | Loss: 0.0111 | Acc: 0.9747 | AUROC: 0.8712 | AUPRC: 0.1920 | Precision: 0.2378 | Recall: 0.2010 | Specificity: 0.9885 | F1: 0.2179
# Confusion Matrix: TN=10727  FP=125  FN=155  TP=39
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1920)
# Starting epoch 16/30... | LR: 0.00001000
# Validation | Loss: 0.0116 | Acc: 0.9733 | AUROC: 0.8635 | AUPRC: 0.1964 | Precision: 0.2488 | Recall: 0.2577 | Specificity: 0.9861 | F1: 0.2532
# Confusion Matrix: TN=10701  FP=151  FN=144  TP=50
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1964)
# Starting epoch 17/30... | LR: 0.00001000
# Validation | Loss: 0.0117 | Acc: 0.9747 | AUROC: 0.8649 | AUPRC: 0.1995 | Precision: 0.2500 | Recall: 0.2216 | Specificity: 0.9881 | F1: 0.2350
# Confusion Matrix: TN=10723  FP=129  FN=151  TP=43
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1995)
# Starting epoch 18/30... | LR: 0.00001000
# Validation | Loss: 0.0111 | Acc: 0.9745 | AUROC: 0.8766 | AUPRC: 0.2140 | Precision: 0.2471 | Recall: 0.2216 | Specificity: 0.9879 | F1: 0.2337
# Confusion Matrix: TN=10721  FP=131  FN=151  TP=43
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2140)
# Starting epoch 19/30... | LR: 0.00001000
# Validation | Loss: 0.0115 | Acc: 0.9720 | AUROC: 0.8733 | AUPRC: 0.2089 | Precision: 0.2300 | Recall: 0.2526 | Specificity: 0.9849 | F1: 0.2408
# Confusion Matrix: TN=10688  FP=164  FN=145  TP=49
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 20/30... | LR: 0.00001000
# Validation | Loss: 0.0114 | Acc: 0.9750 | AUROC: 0.8759 | AUPRC: 0.2115 | Precision: 0.2772 | Recall: 0.2629 | Specificity: 0.9877 | F1: 0.2698
# Confusion Matrix: TN=10719  FP=133  FN=143  TP=51
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 21/30... | LR: 0.00001000
# Validation | Loss: 0.0117 | Acc: 0.9717 | AUROC: 0.8736 | AUPRC: 0.2172 | Precision: 0.2356 | Recall: 0.2732 | Specificity: 0.9842 | F1: 0.2530
# Confusion Matrix: TN=10680  FP=172  FN=141  TP=53
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2172)
# Starting epoch 22/30... | LR: 0.00001000
# Validation | Loss: 0.0117 | Acc: 0.9696 | AUROC: 0.8736 | AUPRC: 0.2159 | Precision: 0.2160 | Recall: 0.2784 | Specificity: 0.9819 | F1: 0.2432
# Confusion Matrix: TN=10656  FP=196  FN=140  TP=54
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 23/30... | LR: 0.00001000
# Validation | Loss: 0.0116 | Acc: 0.9680 | AUROC: 0.8763 | AUPRC: 0.2187 | Precision: 0.2151 | Recall: 0.3093 | Specificity: 0.9798 | F1: 0.2537
# Confusion Matrix: TN=10633  FP=219  FN=134  TP=60
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2187)
# Starting epoch 24/30... | LR: 0.00001000
# Validation | Loss: 0.0121 | Acc: 0.9733 | AUROC: 0.8703 | AUPRC: 0.2250 | Precision: 0.2512 | Recall: 0.2629 | Specificity: 0.9860 | F1: 0.2569
# Confusion Matrix: TN=10700  FP=152  FN=143  TP=51
# Epoch duration: 59.0s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2250)
# Starting epoch 25/30... | LR: 0.00001000
# Validation | Loss: 0.0125 | Acc: 0.9747 | AUROC: 0.8691 | AUPRC: 0.2305 | Precision: 0.2688 | Recall: 0.2577 | Specificity: 0.9875 | F1: 0.2632
# Confusion Matrix: TN=10716  FP=136  FN=144  TP=50
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2305)
# Starting epoch 26/30... | LR: 0.00001000
# Validation | Loss: 0.0118 | Acc: 0.9728 | AUROC: 0.8758 | AUPRC: 0.2290 | Precision: 0.2643 | Recall: 0.3093 | Specificity: 0.9846 | F1: 0.2850
# Confusion Matrix: TN=10685  FP=167  FN=134  TP=60
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 27/30... | LR: 0.00001000
# Validation | Loss: 0.0127 | Acc: 0.9731 | AUROC: 0.8657 | AUPRC: 0.2276 | Precision: 0.2627 | Recall: 0.2938 | Specificity: 0.9853 | F1: 0.2774
# Confusion Matrix: TN=10692  FP=160  FN=137  TP=57
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 28/30... | LR: 0.00001000
# Validation | Loss: 0.0126 | Acc: 0.9716 | AUROC: 0.8729 | AUPRC: 0.2290 | Precision: 0.2458 | Recall: 0.2990 | Specificity: 0.9836 | F1: 0.2698
# Confusion Matrix: TN=10674  FP=178  FN=136  TP=58
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 29/30... | LR: 0.00001000
# Validation | Loss: 0.0130 | Acc: 0.9747 | AUROC: 0.8666 | AUPRC: 0.2261 | Precision: 0.2688 | Recall: 0.2577 | Specificity: 0.9875 | F1: 0.2632
# Confusion Matrix: TN=10716  FP=136  FN=144  TP=50
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 30/30... | LR: 0.00001000
# Validation | Loss: 0.0129 | Acc: 0.9713 | AUROC: 0.8698 | AUPRC: 0.2267 | Precision: 0.2510 | Recall: 0.3196 | Specificity: 0.9830 | F1: 0.2812
# Confusion Matrix: TN=10667  FP=185  FN=132  TP=62
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Fold 0 best AUPRC: 0.2305 (epoch 25)
# Saved history to: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_0_history.csv
#
# ===== Fold 1 =====
# Train size: 22093 | positives: 389
# Val size:   11033 | positives: 195
# Loaded offline weights from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_rwightman-7f5810bc.pth
# Loaded baseline checkpoint from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_final_pre_train_full_ft_5fold_AUPRC_20epochs_balanced_bce_best_model.pth
# Starting epoch 1/30... | LR: 0.00001000
# Validation | Loss: 0.0175 | Acc: 0.9818 | AUROC: 0.6977 | AUPRC: 0.0345 | Precision: 0.0000 | Recall: 0.0000 | Specificity: 0.9994 | F1: 0.0000
# Confusion Matrix: TN=10832  FP=6  FN=195  TP=0
# Epoch duration: 59.0s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.0345)
# Starting epoch 2/30... | LR: 0.00001000
# Validation | Loss: 0.0130 | Acc: 0.9824 | AUROC: 0.7896 | AUPRC: 0.0732 | Precision: 1.0000 | Recall: 0.0051 | Specificity: 1.0000 | F1: 0.0102
# Confusion Matrix: TN=10838  FP=0  FN=194  TP=1
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.0732)
# Starting epoch 3/30... | LR: 0.00001000
# Validation | Loss: 0.0120 | Acc: 0.9822 | AUROC: 0.8328 | AUPRC: 0.1120 | Precision: 0.3333 | Recall: 0.0051 | Specificity: 0.9998 | F1: 0.0101
# Confusion Matrix: TN=10836  FP=2  FN=194  TP=1
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1120)
# Starting epoch 4/30... | LR: 0.00001000
# Validation | Loss: 0.0117 | Acc: 0.9821 | AUROC: 0.8451 | AUPRC: 0.1321 | Precision: 0.4615 | Recall: 0.0615 | Specificity: 0.9987 | F1: 0.1086
# Confusion Matrix: TN=10824  FP=14  FN=183  TP=12
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1321)
# Starting epoch 5/30... | LR: 0.00001000
# Validation | Loss: 0.0112 | Acc: 0.9821 | AUROC: 0.8588 | AUPRC: 0.1442 | Precision: 0.4643 | Recall: 0.0667 | Specificity: 0.9986 | F1: 0.1166
# Confusion Matrix: TN=10823  FP=15  FN=182  TP=13
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1442)
# Starting epoch 6/30... | LR: 0.00001000
# Validation | Loss: 0.0112 | Acc: 0.9817 | AUROC: 0.8609 | AUPRC: 0.1458 | Precision: 0.4286 | Recall: 0.1077 | Specificity: 0.9974 | F1: 0.1721
# Confusion Matrix: TN=10810  FP=28  FN=174  TP=21
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1458)
# Starting epoch 7/30... | LR: 0.00001000
# Validation | Loss: 0.0108 | Acc: 0.9804 | AUROC: 0.8693 | AUPRC: 0.1551 | Precision: 0.3433 | Recall: 0.1179 | Specificity: 0.9959 | F1: 0.1756
# Confusion Matrix: TN=10794  FP=44  FN=172  TP=23
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1551)
# Starting epoch 8/30... | LR: 0.00001000
# Validation | Loss: 0.0107 | Acc: 0.9795 | AUROC: 0.8746 | AUPRC: 0.1620 | Precision: 0.3176 | Recall: 0.1385 | Specificity: 0.9946 | F1: 0.1929
# Confusion Matrix: TN=10780  FP=58  FN=168  TP=27
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1620)
# Starting epoch 9/30... | LR: 0.00001000
# Validation | Loss: 0.0107 | Acc: 0.9797 | AUROC: 0.8745 | AUPRC: 0.1707 | Precision: 0.3371 | Recall: 0.1538 | Specificity: 0.9946 | F1: 0.2113
# Confusion Matrix: TN=10779  FP=59  FN=165  TP=30
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1707)
# Starting epoch 10/30... | LR: 0.00001000
# Validation | Loss: 0.0107 | Acc: 0.9778 | AUROC: 0.8739 | AUPRC: 0.1726 | Precision: 0.2881 | Recall: 0.1744 | Specificity: 0.9922 | F1: 0.2173
# Confusion Matrix: TN=10754  FP=84  FN=161  TP=34
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1726)
# Starting epoch 11/30... | LR: 0.00001000
# Validation | Loss: 0.0105 | Acc: 0.9786 | AUROC: 0.8796 | AUPRC: 0.1858 | Precision: 0.3010 | Recall: 0.1590 | Specificity: 0.9934 | F1: 0.2081
# Confusion Matrix: TN=10766  FP=72  FN=164  TP=31
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1858)
# Starting epoch 12/30... | LR: 0.00001000
# Validation | Loss: 0.0104 | Acc: 0.9784 | AUROC: 0.8822 | AUPRC: 0.1979 | Precision: 0.2952 | Recall: 0.1590 | Specificity: 0.9932 | F1: 0.2067
# Confusion Matrix: TN=10764  FP=74  FN=164  TP=31
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1979)
# Starting epoch 13/30... | LR: 0.00001000
# Validation | Loss: 0.0106 | Acc: 0.9759 | AUROC: 0.8796 | AUPRC: 0.1974 | Precision: 0.2680 | Recall: 0.2103 | Specificity: 0.9897 | F1: 0.2356
# Confusion Matrix: TN=10726  FP=112  FN=154  TP=41
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 14/30... | LR: 0.00001000
# Validation | Loss: 0.0106 | Acc: 0.9752 | AUROC: 0.8811 | AUPRC: 0.2022 | Precision: 0.2690 | Recall: 0.2359 | Specificity: 0.9885 | F1: 0.2514
# Confusion Matrix: TN=10713  FP=125  FN=149  TP=46
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2022)
# Starting epoch 15/30... | LR: 0.00001000
# Validation | Loss: 0.0107 | Acc: 0.9739 | AUROC: 0.8809 | AUPRC: 0.2028 | Precision: 0.2640 | Recall: 0.2667 | Specificity: 0.9866 | F1: 0.2653
# Confusion Matrix: TN=10693  FP=145  FN=143  TP=52
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2028)
# Starting epoch 16/30... | LR: 0.00001000
# Validation | Loss: 0.0107 | Acc: 0.9743 | AUROC: 0.8808 | AUPRC: 0.2117 | Precision: 0.2786 | Recall: 0.2872 | Specificity: 0.9866 | F1: 0.2828
# Confusion Matrix: TN=10693  FP=145  FN=139  TP=56
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2117)
# Starting epoch 17/30... | LR: 0.00001000
# Validation | Loss: 0.0107 | Acc: 0.9741 | AUROC: 0.8795 | AUPRC: 0.2110 | Precision: 0.2802 | Recall: 0.2974 | Specificity: 0.9863 | F1: 0.2886
# Confusion Matrix: TN=10689  FP=149  FN=137  TP=58
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 18/30... | LR: 0.00001000
# Validation | Loss: 0.0108 | Acc: 0.9752 | AUROC: 0.8803 | AUPRC: 0.2124 | Precision: 0.2932 | Recall: 0.2872 | Specificity: 0.9875 | F1: 0.2902
# Confusion Matrix: TN=10703  FP=135  FN=139  TP=56
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2124)
# Starting epoch 19/30... | LR: 0.00001000
# Validation | Loss: 0.0109 | Acc: 0.9763 | AUROC: 0.8819 | AUPRC: 0.2100 | Precision: 0.3041 | Recall: 0.2667 | Specificity: 0.9890 | F1: 0.2842
# Confusion Matrix: TN=10719  FP=119  FN=143  TP=52
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 20/30... | LR: 0.00001000
# Validation | Loss: 0.0111 | Acc: 0.9740 | AUROC: 0.8801 | AUPRC: 0.2125 | Precision: 0.2653 | Recall: 0.2667 | Specificity: 0.9867 | F1: 0.2660
# Confusion Matrix: TN=10694  FP=144  FN=143  TP=52
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2125)
# Starting epoch 21/30... | LR: 0.00001000
# Validation | Loss: 0.0111 | Acc: 0.9717 | AUROC: 0.8807 | AUPRC: 0.2159 | Precision: 0.2489 | Recall: 0.2974 | Specificity: 0.9839 | F1: 0.2710
# Confusion Matrix: TN=10663  FP=175  FN=137  TP=58
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2159)
# Starting epoch 22/30... | LR: 0.00001000
# Validation | Loss: 0.0111 | Acc: 0.9749 | AUROC: 0.8805 | AUPRC: 0.2197 | Precision: 0.2887 | Recall: 0.2872 | Specificity: 0.9873 | F1: 0.2879
# Confusion Matrix: TN=10700  FP=138  FN=139  TP=56
# Epoch duration: 59.0s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2197)
# Starting epoch 23/30... | LR: 0.00001000
# Validation | Loss: 0.0112 | Acc: 0.9724 | AUROC: 0.8817 | AUPRC: 0.2233 | Precision: 0.2720 | Recall: 0.3333 | Specificity: 0.9839 | F1: 0.2995
# Confusion Matrix: TN=10664  FP=174  FN=130  TP=65
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2233)
# Starting epoch 24/30... | LR: 0.00001000
# Validation | Loss: 0.0112 | Acc: 0.9686 | AUROC: 0.8823 | AUPRC: 0.2230 | Precision: 0.2351 | Recall: 0.3436 | Specificity: 0.9799 | F1: 0.2792
# Confusion Matrix: TN=10620  FP=218  FN=128  TP=67
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 25/30... | LR: 0.00001000
# Validation | Loss: 0.0118 | Acc: 0.9742 | AUROC: 0.8758 | AUPRC: 0.2142 | Precision: 0.2727 | Recall: 0.2769 | Specificity: 0.9867 | F1: 0.2748
# Confusion Matrix: TN=10694  FP=144  FN=141  TP=54
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 26/30... | LR: 0.00001000
# Validation | Loss: 0.0118 | Acc: 0.9670 | AUROC: 0.8781 | AUPRC: 0.2207 | Precision: 0.2155 | Recall: 0.3282 | Specificity: 0.9785 | F1: 0.2602
# Confusion Matrix: TN=10605  FP=233  FN=131  TP=64
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 27/30... | LR: 0.00001000
# Validation | Loss: 0.0116 | Acc: 0.9700 | AUROC: 0.8796 | AUPRC: 0.2208 | Precision: 0.2424 | Recall: 0.3282 | Specificity: 0.9815 | F1: 0.2789
# Confusion Matrix: TN=10638  FP=200  FN=131  TP=64
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 28/30... | LR: 0.00001000
# Validation | Loss: 0.0120 | Acc: 0.9724 | AUROC: 0.8777 | AUPRC: 0.2154 | Precision: 0.2511 | Recall: 0.2821 | Specificity: 0.9849 | F1: 0.2657
# Confusion Matrix: TN=10674  FP=164  FN=140  TP=55
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 29/30... | LR: 0.00001000
# Validation | Loss: 0.0125 | Acc: 0.9745 | AUROC: 0.8760 | AUPRC: 0.2094 | Precision: 0.2760 | Recall: 0.2718 | Specificity: 0.9872 | F1: 0.2739
# Confusion Matrix: TN=10699  FP=139  FN=142  TP=53
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 30/30... | LR: 0.00001000
# Validation | Loss: 0.0122 | Acc: 0.9670 | AUROC: 0.8778 | AUPRC: 0.2150 | Precision: 0.2174 | Recall: 0.3333 | Specificity: 0.9784 | F1: 0.2632
# Confusion Matrix: TN=10604  FP=234  FN=130  TP=65
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Fold 1 best AUPRC: 0.2233 (epoch 23)
# Saved history to: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_1_history.csv
#
# ===== Fold 2 =====
# Train size: 22079 | positives: 389
# Val size:   11047 | positives: 195
# Loaded offline weights from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_rwightman-7f5810bc.pth
# Loaded baseline checkpoint from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_final_pre_train_full_ft_5fold_AUPRC_20epochs_balanced_bce_best_model.pth
# Starting epoch 1/30... | LR: 0.00001000
# Validation | Loss: 0.0177 | Acc: 0.9734 | AUROC: 0.7260 | AUPRC: 0.0508 | Precision: 0.0769 | Recall: 0.0462 | Specificity: 0.9900 | F1: 0.0577
# Confusion Matrix: TN=10744  FP=108  FN=186  TP=9
# Epoch duration: 59.1s (0.99 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.0508)
# Starting epoch 2/30... | LR: 0.00001000
# Validation | Loss: 0.0132 | Acc: 0.9785 | AUROC: 0.8066 | AUPRC: 0.0890 | Precision: 0.1719 | Recall: 0.0564 | Specificity: 0.9951 | F1: 0.0849
# Confusion Matrix: TN=10799  FP=53  FN=184  TP=11
# Epoch duration: 61.6s (1.03 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.0890)
# Starting epoch 3/30... | LR: 0.00001000
# Validation | Loss: 0.0118 | Acc: 0.9787 | AUROC: 0.8404 | AUPRC: 0.1266 | Precision: 0.2674 | Recall: 0.1179 | Specificity: 0.9942 | F1: 0.1637
# Confusion Matrix: TN=10789  FP=63  FN=172  TP=23
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1266)
# Starting epoch 4/30... | LR: 0.00001000
# Validation | Loss: 0.0112 | Acc: 0.9788 | AUROC: 0.8570 | AUPRC: 0.1448 | Precision: 0.2759 | Recall: 0.1231 | Specificity: 0.9942 | F1: 0.1702
# Confusion Matrix: TN=10789  FP=63  FN=171  TP=24
# Epoch duration: 58.7s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1448)
# Starting epoch 5/30... | LR: 0.00001000
# Validation | Loss: 0.0109 | Acc: 0.9787 | AUROC: 0.8658 | AUPRC: 0.1710 | Precision: 0.2959 | Recall: 0.1487 | Specificity: 0.9936 | F1: 0.1980
# Confusion Matrix: TN=10783  FP=69  FN=166  TP=29
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1710)
# Starting epoch 6/30... | LR: 0.00001000
# Validation | Loss: 0.0106 | Acc: 0.9795 | AUROC: 0.8706 | AUPRC: 0.1783 | Precision: 0.3182 | Recall: 0.1436 | Specificity: 0.9945 | F1: 0.1979
# Confusion Matrix: TN=10792  FP=60  FN=167  TP=28
# Epoch duration: 58.7s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1783)
# Starting epoch 7/30... | LR: 0.00001000
# Validation | Loss: 0.0106 | Acc: 0.9784 | AUROC: 0.8702 | AUPRC: 0.1780 | Precision: 0.2800 | Recall: 0.1436 | Specificity: 0.9934 | F1: 0.1898
# Confusion Matrix: TN=10780  FP=72  FN=167  TP=28
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 8/30... | LR: 0.00001000
# Validation | Loss: 0.0106 | Acc: 0.9762 | AUROC: 0.8743 | AUPRC: 0.1924 | Precision: 0.2792 | Recall: 0.2205 | Specificity: 0.9898 | F1: 0.2464
# Confusion Matrix: TN=10741  FP=111  FN=152  TP=43
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.1924)
# Starting epoch 9/30... | LR: 0.00001000
# Validation | Loss: 0.0104 | Acc: 0.9757 | AUROC: 0.8818 | AUPRC: 0.2008 | Precision: 0.2890 | Recall: 0.2564 | Specificity: 0.9887 | F1: 0.2717
# Confusion Matrix: TN=10729  FP=123  FN=145  TP=50
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2008)
# Starting epoch 10/30... | LR: 0.00001000
# Validation | Loss: 0.0104 | Acc: 0.9773 | AUROC: 0.8807 | AUPRC: 0.2030 | Precision: 0.3082 | Recall: 0.2308 | Specificity: 0.9907 | F1: 0.2639
# Confusion Matrix: TN=10751  FP=101  FN=150  TP=45
# Epoch duration: 58.7s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2030)
# Starting epoch 11/30... | LR: 0.00001000
# Validation | Loss: 0.0103 | Acc: 0.9764 | AUROC: 0.8830 | AUPRC: 0.2095 | Precision: 0.2938 | Recall: 0.2410 | Specificity: 0.9896 | F1: 0.2648
# Confusion Matrix: TN=10739  FP=113  FN=148  TP=47
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2095)
# Starting epoch 12/30... | LR: 0.00001000
# Validation | Loss: 0.0103 | Acc: 0.9763 | AUROC: 0.8834 | AUPRC: 0.2054 | Precision: 0.2970 | Recall: 0.2513 | Specificity: 0.9893 | F1: 0.2722
# Confusion Matrix: TN=10736  FP=116  FN=146  TP=49
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 13/30... | LR: 0.00001000
# Validation | Loss: 0.0105 | Acc: 0.9743 | AUROC: 0.8829 | AUPRC: 0.2140 | Precision: 0.2871 | Recall: 0.3077 | Specificity: 0.9863 | F1: 0.2970
# Confusion Matrix: TN=10703  FP=149  FN=135  TP=60
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2140)
# Starting epoch 14/30... | LR: 0.00001000
# Validation | Loss: 0.0103 | Acc: 0.9764 | AUROC: 0.8885 | AUPRC: 0.2256 | Precision: 0.3146 | Recall: 0.2872 | Specificity: 0.9888 | F1: 0.3003
# Confusion Matrix: TN=10730  FP=122  FN=139  TP=56
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2256)
# Starting epoch 15/30... | LR: 0.00001000
# Validation | Loss: 0.0105 | Acc: 0.9777 | AUROC: 0.8859 | AUPRC: 0.2304 | Precision: 0.3355 | Recall: 0.2667 | Specificity: 0.9905 | F1: 0.2971
# Confusion Matrix: TN=10749  FP=103  FN=143  TP=52
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2304)
# Starting epoch 16/30... | LR: 0.00001000
# Validation | Loss: 0.0106 | Acc: 0.9738 | AUROC: 0.8849 | AUPRC: 0.2362 | Precision: 0.2883 | Recall: 0.3282 | Specificity: 0.9854 | F1: 0.3070
# Confusion Matrix: TN=10694  FP=158  FN=131  TP=64
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2362)
# Starting epoch 17/30... | LR: 0.00001000
# Validation | Loss: 0.0104 | Acc: 0.9771 | AUROC: 0.8899 | AUPRC: 0.2444 | Precision: 0.3294 | Recall: 0.2872 | Specificity: 0.9895 | F1: 0.3068
# Confusion Matrix: TN=10738  FP=114  FN=139  TP=56
# Epoch duration: 58.7s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2444)
# Starting epoch 18/30... | LR: 0.00001000
# Validation | Loss: 0.0104 | Acc: 0.9751 | AUROC: 0.8873 | AUPRC: 0.2426 | Precision: 0.3039 | Recall: 0.3179 | Specificity: 0.9869 | F1: 0.3108
# Confusion Matrix: TN=10710  FP=142  FN=133  TP=62
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 19/30... | LR: 0.00001000
# Validation | Loss: 0.0105 | Acc: 0.9743 | AUROC: 0.8887 | AUPRC: 0.2549 | Precision: 0.2930 | Recall: 0.3231 | Specificity: 0.9860 | F1: 0.3073
# Confusion Matrix: TN=10700  FP=152  FN=132  TP=63
# Epoch duration: 58.7s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2549)
# Starting epoch 20/30... | LR: 0.00001000
# Validation | Loss: 0.0109 | Acc: 0.9709 | AUROC: 0.8887 | AUPRC: 0.2435 | Precision: 0.2548 | Recall: 0.3385 | Specificity: 0.9822 | F1: 0.2907
# Confusion Matrix: TN=10659  FP=193  FN=129  TP=66
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 21/30... | LR: 0.00001000
# Validation | Loss: 0.0110 | Acc: 0.9749 | AUROC: 0.8844 | AUPRC: 0.2453 | Precision: 0.2929 | Recall: 0.2974 | Specificity: 0.9871 | F1: 0.2952
# Confusion Matrix: TN=10712  FP=140  FN=137  TP=58
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 22/30... | LR: 0.00001000
# Validation | Loss: 0.0112 | Acc: 0.9752 | AUROC: 0.8854 | AUPRC: 0.2400 | Precision: 0.2932 | Recall: 0.2872 | Specificity: 0.9876 | F1: 0.2902
# Confusion Matrix: TN=10717  FP=135  FN=139  TP=56
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 23/30... | LR: 0.00001000
# Validation | Loss: 0.0114 | Acc: 0.9720 | AUROC: 0.8849 | AUPRC: 0.2535 | Precision: 0.2683 | Recall: 0.3385 | Specificity: 0.9834 | F1: 0.2993
# Confusion Matrix: TN=10672  FP=180  FN=129  TP=66
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 24/30... | LR: 0.00001000
# Validation | Loss: 0.0117 | Acc: 0.9730 | AUROC: 0.8821 | AUPRC: 0.2445 | Precision: 0.2627 | Recall: 0.2923 | Specificity: 0.9853 | F1: 0.2767
# Confusion Matrix: TN=10692  FP=160  FN=138  TP=57
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 25/30... | LR: 0.00001000
# Validation | Loss: 0.0122 | Acc: 0.9729 | AUROC: 0.8772 | AUPRC: 0.2533 | Precision: 0.2679 | Recall: 0.3077 | Specificity: 0.9849 | F1: 0.2864
# Confusion Matrix: TN=10688  FP=164  FN=135  TP=60
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 26/30... | LR: 0.00001000
# Validation | Loss: 0.0119 | Acc: 0.9732 | AUROC: 0.8820 | AUPRC: 0.2577 | Precision: 0.2715 | Recall: 0.3077 | Specificity: 0.9852 | F1: 0.2885
# Confusion Matrix: TN=10691  FP=161  FN=135  TP=60
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2577)
# Starting epoch 27/30... | LR: 0.00001000
# Validation | Loss: 0.0121 | Acc: 0.9728 | AUROC: 0.8823 | AUPRC: 0.2597 | Precision: 0.2624 | Recall: 0.2974 | Specificity: 0.9850 | F1: 0.2788
# Confusion Matrix: TN=10689  FP=163  FN=137  TP=58
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2597)
# Starting epoch 28/30... | LR: 0.00001000
# Validation | Loss: 0.0123 | Acc: 0.9721 | AUROC: 0.8830 | AUPRC: 0.2686 | Precision: 0.2616 | Recall: 0.3179 | Specificity: 0.9839 | F1: 0.2870
# Confusion Matrix: TN=10677  FP=175  FN=133  TP=62
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Best model saved (AUPRC 0.2686)
# Starting epoch 29/30... | LR: 0.00001000
# Validation | Loss: 0.0126 | Acc: 0.9715 | AUROC: 0.8814 | AUPRC: 0.2649 | Precision: 0.2619 | Recall: 0.3385 | Specificity: 0.9829 | F1: 0.2953
# Confusion Matrix: TN=10666  FP=186  FN=129  TP=66
# Epoch duration: 58.9s (0.98 min)
# ------------------------------------------------------------
# Starting epoch 30/30... | LR: 0.00001000
# Validation | Loss: 0.0130 | Acc: 0.9721 | AUROC: 0.8812 | AUPRC: 0.2594 | Precision: 0.2656 | Recall: 0.3282 | Specificity: 0.9837 | F1: 0.2936
# Confusion Matrix: TN=10675  FP=177  FN=131  TP=64
# Epoch duration: 58.8s (0.98 min)
# ------------------------------------------------------------
# Fold 2 best AUPRC: 0.2686 (epoch 28)
# Saved history to: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_2_history.csv
# Saved CV summary to: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_cv_summary.txt

# %% [markdown]
# # Plotting

# %%
for fold_idx in FOLDS_TO_RUN:
    history_path = WORKING_DIR / f"{EXPERIMENT_NAME}_fold_{fold_idx}_history.csv"
    history_df = pd.read_csv(history_path)

    loss_plot_path  = WORKING_DIR / f"{EXPERIMENT_NAME}_fold_{fold_idx}_loss.png"
    auroc_plot_path = WORKING_DIR / f"{EXPERIMENT_NAME}_fold_{fold_idx}_auroc.png"
    score_plot_path = WORKING_DIR / f"{EXPERIMENT_NAME}_fold_{fold_idx}_auprc_f1.png"

    # Loss
    plt.figure(figsize=(8, 5))
    plt.plot(history_df["epoch"], history_df["train_loss"], label="train_loss")
    plt.plot(history_df["epoch"], history_df["val_loss"], label="val_loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"Fold {fold_idx} - Loss")
    plt.legend()
    plt.grid(True)
    plt.savefig(loss_plot_path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close()

    # AUROC
    plt.figure(figsize=(8, 5))
    plt.plot(history_df["epoch"], history_df["train_auroc"], label="train_auroc")
    plt.plot(history_df["epoch"], history_df["val_auroc"], label="val_auroc")
    plt.xlabel("Epoch")
    plt.ylabel("AUROC")
    plt.title(f"Fold {fold_idx} - AUROC")
    plt.legend()
    plt.grid(True)
    plt.savefig(auroc_plot_path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close()

    # AUPRC / F1
    plt.figure(figsize=(8, 5))
    plt.plot(history_df["epoch"], history_df["val_auprc"], label="val_auprc")
    plt.plot(history_df["epoch"], history_df["val_f1"], label="val_f1")
    plt.xlabel("Epoch")
    plt.ylabel("Score")
    plt.title(f"Fold {fold_idx} - AUPRC / F1")
    plt.legend()
    plt.grid(True)
    plt.savefig(score_plot_path, dpi=150, bbox_inches="tight")
    plt.show()
    plt.close()

    print(f"Saved: {loss_plot_path}")
    print(f"Saved: {auroc_plot_path}")
    print(f"Saved: {score_plot_path}")
# Out:
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_0_loss.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_0_auroc.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_0_auprc_f1.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_1_loss.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_1_auroc.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_1_auprc_f1.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_2_loss.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_2_auroc.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_2_auprc_f1.png

# %% [markdown]
# # OOF and TTA

# %%
USE_TTA_EVAL = True

oof_probs = []
oof_labels = []
oof_records = []
fold_oof_results = []

for fold_idx, train_idx, val_idx in fold_splits:
    print(f"\n===== OOF evaluation fold {fold_idx} =====")

    train_df = df.iloc[train_idx].reset_index(drop=True)
    val_df   = df.iloc[val_idx].reset_index(drop=True)

    val_loader = make_val_loader(val_df)

    model = build_model()
    BEST_MODEL_PATH, _, _ = get_fold_paths(fold_idx)

    state_dict = torch.load(BEST_MODEL_PATH, map_location="cpu", weights_only=True)
    model.load_state_dict(state_dict)
    model = model.to(device)
    model.eval()

    criterion, _ = build_training_components(model, train_df)


    val_metrics = validate_one_epoch(
        model,
        val_loader,
        criterion,
        device,
        use_tta=USE_TTA_EVAL
    )

    fold_oof_results.append({
        "fold": fold_idx,
        "auroc": val_metrics["auroc"],
        "auprc": val_metrics["auprc"],
        "f1": val_metrics["f1"],
    })

    fold_probs = val_metrics["all_probs"]
    fold_labels = val_metrics["all_labels"]

    fold_pred_df = val_df[["image_name", "target"]].copy()
    fold_pred_df["fold"] = fold_idx
    fold_pred_df["prob"] = fold_probs
    fold_pred_df["pred_05"] = (fold_pred_df["prob"] >= 0.5).astype(int)

    fold_csv_path = WORKING_DIR / f"{EXPERIMENT_NAME}_fold_{fold_idx}_val_predictions.csv"
    fold_pred_df.to_csv(fold_csv_path, index=False)
    print(f"Saved: {fold_csv_path}")

    oof_records.append(fold_pred_df)
    oof_probs.extend(fold_probs)
    oof_labels.extend(fold_labels)

oof_probs = np.array(oof_probs)
oof_labels = np.array(oof_labels)

oof_pred_df = pd.concat(oof_records, axis=0, ignore_index=True)
oof_pred_path = WORKING_DIR / f"{EXPERIMENT_NAME}_oof_predictions.csv"
oof_pred_df.to_csv(oof_pred_path, index=False)

oof_auroc = roc_auc_score(oof_labels, oof_probs)
oof_auprc = average_precision_score(oof_labels, oof_probs)


# Define the path for the OOF summary text file
oof_summary_txt_path = WORKING_DIR / f"{EXPERIMENT_NAME}_oof_summary.txt"

# Open the file in write mode ("w")
with open(oof_summary_txt_path, "w") as f:
    
    # Log per-fold metrics
    title_fold = "===== Per-fold OOF metrics ====="
    print(f"\n{title_fold}")
    f.write(f"{title_fold}\n")
    
    for result in fold_oof_results:
        line = (
            f"Fold {result['fold']} | "
            f"AUROC: {result['auroc']:.4f} | "
            f"AUPRC: {result['auprc']:.4f} | "
            f"F1@0.5: {result['f1']:.4f}"
        )
        print(line)
        f.write(f"{line}\n")
        
    # Log global metrics
    title_global = "===== Global OOF metrics ====="
    print(f"\n{title_global}")
    f.write(f"\n{title_global}\n")
    
    line_auroc = f"OOF AUROC: {oof_auroc:.4f}"
    line_auprc = f"OOF AUPRC: {oof_auprc:.4f}"
    
    print(line_auroc)
    print(line_auprc)
    f.write(f"{line_auroc}\n")
    f.write(f"{line_auprc}\n")

# Console confirmation
print(f"\nSaved OOF metrics summary to: {oof_summary_txt_path}")

oof_threshold_df = threshold_sweep(oof_labels, oof_probs)
oof_threshold_path = WORKING_DIR / f"{EXPERIMENT_NAME}_oof_threshold_sweep.csv"
oof_threshold_df.to_csv(oof_threshold_path, index=False)

display(oof_threshold_df)

best_idx = oof_threshold_df["f1"].idxmax()
best_row = oof_threshold_df.loc[best_idx]
best_thr = float(best_row["threshold"])

print("\nBest OOF threshold by F1:")
print(best_row)

# APPEND BEST THRESHOLD TO THE SUMMARY TXT

with open(oof_summary_txt_path, "a") as f:  
    f.write("\n===== Best OOF Threshold by F1 =====\n")
    f.write(f"Threshold: {best_thr:.4f}\n")
    f.write(f"F1 Score:  {best_row['f1']:.4f}\n")
    f.write(f"Precision: {best_row['precision']:.4f}\n")
    f.write(f"Recall:    {best_row['recall']:.4f}\n")

print(f"\nAppended best threshold metrics to: {oof_summary_txt_path}")
# Out:
# ===== OOF evaluation fold 0 =====
# Loaded offline weights from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_rwightman-7f5810bc.pth
# Loaded baseline checkpoint from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_final_pre_train_full_ft_5fold_AUPRC_20epochs_balanced_bce_best_model.pth
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_0_val_predictions.csv
#
# ===== OOF evaluation fold 1 =====
# Loaded offline weights from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_rwightman-7f5810bc.pth
# Loaded baseline checkpoint from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_final_pre_train_full_ft_5fold_AUPRC_20epochs_balanced_bce_best_model.pth
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_1_val_predictions.csv
#
# ===== OOF evaluation fold 2 =====
# Loaded offline weights from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_rwightman-7f5810bc.pth
# Loaded baseline checkpoint from /user/HS401/ep01372/Documents/AML_Project/inputs/efficientnet_b0_final_pre_train_full_ft_5fold_AUPRC_20epochs_balanced_bce_best_model.pth
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_fold_2_val_predictions.csv
#
# ===== Per-fold OOF metrics =====
# Fold 0 | AUROC: 0.8723 | AUPRC: 0.2291 | F1@0.5: 0.2703
# Fold 1 | AUROC: 0.8831 | AUPRC: 0.2360 | F1@0.5: 0.2885
# Fold 2 | AUROC: 0.8847 | AUPRC: 0.2623 | F1@0.5: 0.2930
#
# ===== Global OOF metrics =====
# OOF AUROC: 0.8781
# OOF AUPRC: 0.2347
#
# Saved OOF metrics summary to: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_oof_summary.txt
#     threshold  precision    recall        f1  specificity
# 0        0.05   0.027005  0.974315  0.052554     0.370014
# 1        0.10   0.040399  0.914384  0.077380     0.610227
# 2        0.15   0.054558  0.842466  0.102479     0.738000
# 3        0.20   0.070728  0.765411  0.129490     0.819526
# 4        0.25   0.089729  0.698630  0.159033     0.872811
# 5        0.30   0.110222  0.613014  0.186848     0.911192
# 6        0.35   0.139150  0.532534  0.220646     0.940876
# 7        0.40   0.175623  0.458904  0.254028     0.961342
# 8        0.45   0.218872  0.385274  0.279156     0.975324
# 9        0.50   0.273734  0.296233  0.284539     0.985895
# 10       0.55   0.361257  0.236301  0.285714     0.992502
# 11       0.60   0.446009  0.162671  0.238394     0.996374
# 12       0.65   0.543860  0.106164  0.177650     0.998402
# 13       0.70   0.687500  0.056507  0.104430     0.999539
# 14       0.75   0.857143  0.020548  0.040134     0.999939
# 15       0.80   1.000000  0.001712  0.003419     1.000000
# 16       0.85   0.000000  0.000000  0.000000     1.000000
# 17       0.90   0.000000  0.000000  0.000000     1.000000
# 18       0.95   0.000000  0.000000  0.000000     1.000000
# Best OOF threshold by F1:
# threshold      0.550000
# precision      0.361257
# recall         0.236301
# f1             0.285714
# specificity    0.992502
# Name: 10, dtype: float64
#
# Appended best threshold metrics to: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_oof_summary.txt

# %%
def save_confusion_matrix_figure(y_true, y_prob, threshold, save_path, title):
    y_pred = (y_prob >= threshold).astype(int)
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    class_labels = ['Benign', 'Melanoma']

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    fig, ax = plt.subplots(figsize=(6, 6))
    disp.plot(ax=ax, cmap="Blues", colorbar=False)
    ax.set_title(title)
    plt.tight_layout()
    plt.savefig(save_path, bbox_inches="tight")
    plt.show()

    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0

    metrics = {
        "threshold": threshold,
        "tn": int(tn),
        "fp": int(fp),
        "fn": int(fn),
        "tp": int(tp),
        "precision": float(precision_score(y_true, y_pred, zero_division=0)),
        "recall": float(recall_score(y_true, y_pred, zero_division=0)),
        "f1": float(f1_score(y_true, y_pred, zero_division=0)),
        "specificity": float(specificity),
    }
    return metrics

cm_05_path = WORKING_DIR / f"{EXPERIMENT_NAME}_oof_confusion_matrix_t050.png"
cm_best_path = WORKING_DIR / f"{EXPERIMENT_NAME}_oof_confusion_matrix_best_f1.png"

cm_metrics_05 = save_confusion_matrix_figure(
    oof_labels,
    oof_probs,
    threshold=0.5,
    save_path=cm_05_path,
    title="OOF Confusion Matrix @ threshold=0.50"
)

cm_metrics_best = save_confusion_matrix_figure(
    oof_labels,
    oof_probs,
    threshold=best_thr,
    save_path=cm_best_path,
    title=f"OOF Confusion Matrix @ best F1 threshold={best_thr:.2f}"
)

oof_metrics = {
    "oof_auroc": float(oof_auroc),
    "oof_auprc": float(oof_auprc),
    "best_f1_threshold": best_thr,
    "cm_at_050": cm_metrics_05,
    "cm_at_best_f1": cm_metrics_best,
}

metrics_path = WORKING_DIR / f"{EXPERIMENT_NAME}_oof_metrics.json"
with open(metrics_path, "w") as f:
    import json
    json.dump(oof_metrics, f, indent=2)

print(f"\nSaved: {oof_pred_path}")
print(f"Saved: {oof_threshold_path}")
print(f"Saved: {cm_05_path}")
print(f"Saved: {cm_best_path}")
print(f"Saved: {metrics_path}")
# Out:
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_oof_predictions.csv
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_oof_threshold_sweep.csv
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_oof_confusion_matrix_t050.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_oof_confusion_matrix_best_f1.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_oof_metrics.json

# %%
roc_path = WORKING_DIR / f"{EXPERIMENT_NAME}_oof_roc.png"
pr_path  = WORKING_DIR / f"{EXPERIMENT_NAME}_oof_pr.png"


fpr, tpr, _ = roc_curve(oof_labels, oof_probs)
precision_pr, recall_pr, _ = precision_recall_curve(oof_labels, oof_probs)

roc_auc = oof_auroc
ap = oof_auprc

# ROC
plt.figure(figsize=(7, 5))
plt.plot(fpr, tpr, label=f"OOF ROC (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], linestyle="--", label="Random")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("OOF ROC Curve")
plt.legend()
plt.grid(True)
plt.savefig(roc_path, bbox_inches="tight")
plt.show()

# PR
plt.figure(figsize=(7, 5))
plt.plot(recall_pr, precision_pr, label=f"OOF PR (AP = {ap:.4f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("OOF Precision-Recall Curve")
plt.legend()
plt.grid(True)
plt.savefig(pr_path, bbox_inches="tight")
plt.show()

print("Saved:", roc_path)
print("Saved:", pr_path)
# Out:
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_oof_roc.png
# Saved: /user/HS401/ep01372/Documents/AML_Project/outputs/efficientnet_b0_transfer_full_ft_FOCAL_alpha_085_3fold_TTA_AUPRC_20epochs_aug_oof_pr.png
